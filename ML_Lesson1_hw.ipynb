# %%
import pandas as pd
train = pd.read_csv('00_titanic_train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train.plot.scatter(x='PassengerId',y='Age',c='Survived',colormap='viridis')

# %%
train.plot.scatter(x='Fare',y='Age',c='Survived',colormap='viridis')

# %%
train.plot.scatter(x='PassengerId',y='Fare',c='Survived',colormap='viridis')

# %%
train['Sex_num'] = train['Sex'].map(lambda x: 1 if x =='male' else 0)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex_num
# 0      0         A/5 21171   7.2500   NaN        S        1
# 1      0          PC 17599  71.2833   C85        C        0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0
# 3      0            113803  53.1000  C123        S        0
# ...

# %%
train.plot.scatter(x='Sex_num',y='Fare',c='Survived',colormap='viridis')

# %%
train.plot.scatter(x='Pclass',y='Fare',c='Survived',colormap='viridis')

# %%
train.plot.scatter(x='Sex_num',y='Survived',c='Survived',colormap='viridis')

# %%
train.plot.scatter(x='PassengerId',y='Parch',c='Survived',colormap='viridis')
